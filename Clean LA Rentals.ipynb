# %%
# !pip install -r requirements.txt

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import base64

# %%
df = pd.read_csv("LA Rentals.csv")
df.drop(df.columns[[0,2,3]],axis=1, inplace=True)
#Remove colums = OG index from CSV, SizeRank, and MsaName
df.rename(columns={'RegionName':'ZipCode'}, inplace=True)
#Rename 'RegionName': 'ZipCode'
df
# Out:
#      ZipCode  2014-01  2014-02  2014-03  2014-04  2014-05  2014-06  2014-07  \
# 0      90004   1571.0      NaN      NaN   1475.0   1426.0   1453.0   1451.0
# 1      90006      NaN   1096.0   1101.0   1094.0   1090.0   1173.0      NaN
# 2      90007   1303.0   1210.0      NaN   1396.0      NaN      NaN      NaN
# 3      90012      NaN      NaN      NaN   1952.0      NaN   2004.0   2088.0
# 4      90013      NaN   1929.0      NaN   2143.0      NaN   1872.0      NaN
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 139    91780      NaN      NaN      NaN      NaN      NaN      NaN   1671.0
# 140    91786   1255.0   1382.0   1353.0   1443.0   1477.0   1485.0   1472.0
# 141    91789      NaN   1912.0   1991.0   2102.0   2209.0   2264.0   2196.0
# 142    91790      NaN      NaN   1817.0      NaN      NaN   1819.0      NaN
# 143    91791   1846.0      NaN   1870.0      NaN      NaN   1900.0   1914.0
#
# ...

# %%
df.dtypes
# Out:
# ZipCode      int64
# 2014-01    float64
# 2014-02    float64
# 2014-03    float64
# 2014-04    float64
#             ...
# 2020-12    float64
# 2021-01    float64
# 2021-02    float64
# 2021-03    float64
# 2021-04      int64
# Length: 89, dtype: object

# %%
#Change RegionName to str
#Change rest of columns to floats
df['ZipCode'] = df['ZipCode'].astype(str)
df['2021-04'] = df['2021-04'].astype(float)
df.dtypes
# Out:
# ZipCode     object
# 2014-01    float64
# 2014-02    float64
# 2014-03    float64
# 2014-04    float64
#             ...
# 2020-12    float64
# 2021-01    float64
# 2021-02    float64
# 2021-03    float64
# 2021-04    float64
# Length: 89, dtype: object

# %%
len(df['ZipCode'].unique()) 
#Run to check for duplicates
#144 Unique values = no duplicates
# Out:
# 144

# %%
#Pivot Table
smol_data = pd.melt(df, id_vars=['ZipCode'],
        value_vars=['2014-01', '2014-02', '2014-03', '2014-04', '2014-05',
       '2014-06', '2014-07', '2014-08', '2014-09', '2014-10', '2014-11',
       '2014-12', '2015-01', '2015-02', '2015-03', '2015-04', '2015-05',
       '2015-06', '2015-07', '2015-08', '2015-09', '2015-10', '2015-11',
       '2015-12', '2016-01', '2016-02', '2016-03', '2016-04', '2016-05',
       '2016-06', '2016-07', '2016-08', '2016-09', '2016-10', '2016-11',
       '2016-12', '2017-01', '2017-02', '2017-03', '2017-04', '2017-05',
       '2017-06', '2017-07', '2017-08', '2017-09', '2017-10', '2017-11',
       '2017-12', '2018-01', '2018-02', '2018-03', '2018-04', '2018-05',
       '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11',
       '2018-12', '2019-01', '2019-02', '2019-03', '2019-04', '2019-05',
       '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11',
       '2019-12', '2020-01', '2020-02', '2020-03', '2020-04', '2020-05',
       '2020-06', '2020-07', '2020-08', '2020-09', '2020-10', '2020-11',
       '2020-12', '2021-01', '2021-02', '2021-03', '2021-04'])
smol_data.rename(columns={'variable':'Month In Year','value':'Average Price'})
# Out:
#       ZipCode Month In Year  Average Price
# 0       90004       2014-01         1571.0
# 1       90006       2014-01            NaN
# 2       90007       2014-01         1303.0
# 3       90012       2014-01            NaN
# 4       90013       2014-01            NaN
# ...       ...           ...            ...
# 12667   91780       2021-04         2338.0
# 12668   91786       2021-04         2062.0
# 12669   91789       2021-04         2850.0
# 12670   91790       2021-04         2357.0
# 12671   91791       2021-04         2131.0
#
# [12672 rows x 3 columns]
